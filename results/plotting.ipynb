# %%
import pickle
import os
import matplotlib.pyplot as plt
# Out:
# C:\Users\boop\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\boop\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\boop\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
files = os.listdir('results')
losses = [f for f in files if 'loss' in f]
losses
# Out:
# ['loss.pkl',
#  'loss_dl_encl.pkl',
#  'loss_dl_encmclr.pkl',
#  'loss_dl_encmclr_dropout0p2.pkl',
#  'loss_dl_encmclr_dropout0p2__noznorm.pkl']

# %%
with open('results/'+losses[1], 'rb') as f:
    loss = pickle.load(f)

# %%
loss[0]
# Out:
# (3.641312852050319, 3.5611070156097413)

# %% [markdown]
# This is from the dl classifier with encoder and classifier

# %%
plt.plot(loss)
plt.show()

# %%
with open('results/'+losses[2], 'rb') as f:
    loss2 = pickle.load(f)

plt.plot(loss2)
plt.show()

# %%
with open('results/'+losses[3], 'rb') as f:
    loss = pickle.load(f)

plt.plot(loss)
plt.show()

# %%
with open('results/'+losses[4], 'rb') as f:
    loss = pickle.load(f)

plt.plot(loss)
plt.show()

# %%
files = os.listdir('from_colab/results')
losses_colab = [f for f in files if 'loss' in f]
losses_colab
# Out:
# ['loss_dl_encl.pkl',
#  'loss_dl_encmclr.pkl',
#  'loss_dl_encmclr2.pkl',
#  'loss_dl_encmclr_l1_drpout.pkl']

# %%
with open('from_colab/results/'+losses_colab[1], 'rb') as f:
    loss = pickle.load(f)

plt.plot(loss)
plt.show()

# %%
with open('from_colab/results/'+losses_colab[2], 'rb') as f:
    print(type(f))
    loss = pickle.load(f)

plt.plot(loss)
plt.show()
# Out:
# <class '_io.BufferedReader'>

# %%
with open('from_colab/results/'+losses_colab[3], 'rb') as f:
    print(type(f))
    loss = pickle.load(f)

plt.plot(loss)
plt.show()
# Out:
# <class '_io.BufferedReader'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [8], line 3
#       1 with open('from_colab/results/'+losses_colab[3], 'rb') as f:
#       2     print(type(f))
# ----> 3     loss = pickle.load(f)
#       5 plt.plot(loss)
#       6 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\storage.py:222, in _load_from_bytes(b)
#     221 def _load_from_bytes(b):
# --> 222     return torch.load(io.BytesIO(b))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\serialization.py:713, in load(f, map_location, pickle_module, **pickle_load_args)
#     711             return torch.jit.load(opened_file)
# ...
